# %%
import pandas as pd
import numpy as np

# === Load Data ===
path = "C:/Users/flass/OneDrive/AI Financial Model/S&P 500 Chatgpt Version/df_labeled.parquet"
df = pd.read_parquet(path)

# Ensure datetime format
df['date'] = pd.to_datetime(df['date'])

# Sort for rolling calculations
df = df.sort_values(['ticker', 'date']).reset_index(drop=True)

# === Technical Indicators ===
def compute_rsi(series, period):
    delta = series.diff()
    up = delta.clip(lower=0)
    down = -1 * delta.clip(upper=0)
    ma_up = up.rolling(period, min_periods=period).mean()
    ma_down = down.rolling(period, min_periods=period).mean()
    rs = ma_up / ma_down
    return 100 - (100 / (1 + rs))

# RSI (daily)
df['rsi_4'] = df.groupby('ticker')['adjusted_close'].transform(lambda x: compute_rsi(x, 4))
df['rsi_7'] = df.groupby('ticker')['adjusted_close'].transform(lambda x: compute_rsi(x, 7))
df['rsi_14'] = df.groupby('ticker')['adjusted_close'].transform(lambda x: compute_rsi(x, 14))
df['rsi_28'] = df.groupby('ticker')['adjusted_close'].transform(lambda x: compute_rsi(x, 28))

# RSI (weekly)
df['week'] = df['date'].dt.to_period('W').dt.start_time
weekly = df.groupby(['ticker', 'week']).agg({
    'adjusted_close': 'last'
}).rename(columns={'adjusted_close': 'weekly_close'}).reset_index()
weekly['rsi_weekly_7'] = weekly.groupby('ticker')['weekly_close'].transform(lambda x: compute_rsi(x, 7))
df = pd.merge(df, weekly[['ticker', 'week', 'rsi_weekly_7']], on=['ticker', 'week'], how='left')
df.drop(columns='week', inplace=True)

# Moving Averages & Relative Price
for period in [50, 100, 200]:
    sma = df.groupby('ticker')['adjusted_close'].transform(lambda x: x.rolling(period, min_periods=period).mean())
    df[f'price_rel_sma{period}d'] = df['adjusted_close'] / sma

for weeks in [26, 52, 156, 260]:
    days = weeks * 5  # approximate trading days
    sma = df.groupby('ticker')['adjusted_close'].transform(lambda x: x.rolling(days, min_periods=days).mean())
    df[f'price_rel_sma{weeks}w'] = df['adjusted_close'] / sma

# Returns
df['returns_1w'] = df.groupby('ticker')['adjusted_close'].transform(lambda x: x.pct_change(5))
df['returns_1m'] = df.groupby('ticker')['adjusted_close'].transform(lambda x: x.pct_change(21))

# MACD
exp12 = df.groupby('ticker')['adjusted_close'].transform(lambda x: x.ewm(span=12, adjust=False).mean())
exp26 = df.groupby('ticker')['adjusted_close'].transform(lambda x: x.ewm(span=26, adjust=False).mean())
df['macd'] = exp12 - exp26
df['macd_signal'] = df.groupby('ticker')['macd'].transform(lambda x: x.ewm(span=9, adjust=False).mean())

# Volume indicators
df['volume_sma_20d'] = df.groupby('ticker')['volume'].transform(lambda x: x.rolling(20, min_periods=20).mean())
df['volume_rel_20d'] = df['volume'] / df['volume_sma_20d']

df['volume_week'] = df.groupby(['ticker', df['date'].dt.to_period('W')])['volume'].transform('sum')
df['volume_sma_12w'] = df.groupby('ticker')['volume_week'].transform(lambda x: x.rolling(12, min_periods=12).mean())
df['volume_rel_12w'] = df['volume_week'] / df['volume_sma_12w']

# Save Output
output_path = "C:/Users/flass/OneDrive/AI Financial Model/S&P 500 Chatgpt Version/df_technical_features.csv"
df.to_csv(output_path, index=False)
print(f"✅ Saved to {output_path}")

# %%
import pandas as pd

file_path = "C:/Users/flass/OneDrive/AI Financial Model/S&P 500 Chatgpt Version/df_model_input.csv"

# Load a small sample
df = pd.read_csv(file_path, nrows=5000)

# Show shape and preview columns
print(f"✅ Loaded technical features file with shape: {df.shape}\n")
print("📋 Columns:")
for col in df.columns:
    print("•", col)
# Out:
# ✅ Loaded technical features file with shape: (5000, 411)
#
# 📋 Columns:
# • date
# • open
# • high
# • low
# • close
# • adjusted_close
# • volume
# • ticker_x
# • ticker_y
# • inc_filing_date
# • inc_currency_symbol
# • inc_researchDevelopment
# • inc_effectOfAccountingCharges
# • inc_incomeBeforeTax
# • inc_minorityInterest
# • inc_netIncome
# • inc_sellingGeneralAdministrative
# • inc_sellingAndMarketingExpenses
# • inc_grossProfit
# • inc_reconciledDepreciation
# • inc_ebit
# • inc_ebitda
# • inc_depreciationAndAmortization
# • inc_nonOperatingIncomeNetOther
# • inc_operatingIncome
# • inc_otherOperatingExpenses
# • inc_interestExpense
# • inc_taxProvision
# • inc_interestIncome
# • inc_netInterestIncome
# • inc_extraordinaryItems
# • inc_nonRecurring
# • inc_otherItems
# • inc_incomeTaxExpense
# • inc_totalRevenue
# • inc_totalOperatingExpenses
# • inc_costOfRevenue
# • inc_totalOtherIncomeExpenseNet
# • inc_discontinuedOperations
# • inc_netIncomeFromContinuingOps
# • inc_netIncomeApplicableToCommonShares
# • inc_preferredStockAndOtherAdjustments
# • inc_totalAssets
# • inc_intangibleAssets
# • inc_earningAssets
# • inc_otherCurrentAssets
# • inc_totalLiab
# • inc_totalStockholderEquity
# • inc_deferredLongTermLiab
# • inc_otherCurrentLiab
# • inc_commonStock
# • inc_capitalStock
# • inc_retainedEarnings
# • inc_otherLiab
# • inc_goodWill
# • inc_otherAssets
# • inc_cash
# • inc_cashAndEquivalents
# • inc_totalCurrentLiabilities
# • inc_currentDeferredRevenue
# • inc_netDebt
# • inc_shortTermDebt
# • inc_shortLongTermDebt
# • inc_shortLongTermDebtTotal
# • inc_otherStockholderEquity
# • inc_propertyPlantEquipment
# • inc_totalCurrentAssets
# • inc_longTermInvestments
# • inc_netTangibleAssets
# • inc_shortTermInvestments
# • inc_netReceivables
# • inc_longTermDebt
# • inc_inventory
# • inc_accountsPayable
# • inc_totalPermanentEquity
# • inc_noncontrollingInterestInConsolidatedEntity
# • inc_temporaryEquityRedeemableNoncontrollingInterests
# • inc_accumulatedOtherComprehensiveIncome
# • inc_additionalPaidInCapital
# • inc_commonStockTotalEquity
# • inc_preferredStockTotalEquity
# • inc_retainedEarningsTotalEquity
# • inc_treasuryStock
# • inc_accumulatedAmortization
# • inc_nonCurrrentAssetsOther
# • inc_deferredLongTermAssetCharges
# • inc_nonCurrentAssetsTotal
# • inc_capitalLeaseObligations
# • inc_longTermDebtTotal
# • inc_nonCurrentLiabilitiesOther
# • inc_nonCurrentLiabilitiesTotal
# • inc_negativeGoodwill
# • inc_warrants
# • inc_preferredStockRedeemable
# • inc_capitalSurpluse
# • inc_liabilitiesAndStockholdersEquity
# • inc_cashAndShortTermInvestments
# • inc_propertyPlantAndEquipmentGross
# • inc_propertyPlantAndEquipmentNet
# • inc_accumulatedDepreciation
# • inc_netWorkingCapital
# • inc_netInvestedCapital
# • inc_commonStockSharesOutstanding
# • inc_investments
# • inc_changeToLiabilities
# • inc_totalCashflowsFromInvestingActivities
# • inc_netBorrowings
# • inc_totalCashFromFinancingActivities
# • inc_changeToOperatingActivities
# • inc_changeInCash
# • inc_beginPeriodCashFlow
# • inc_endPeriodCashFlow
# • inc_totalCashFromOperatingActivities
# • inc_issuanceOfCapitalStock
# • inc_depreciation
# • inc_otherCashflowsFromInvestingActivities
# • inc_dividendsPaid
# • inc_changeToInventory
# • inc_changeToAccountReceivables
# • inc_salePurchaseOfStock
# • inc_otherCashflowsFromFinancingActivities
# • inc_changeToNetincome
# • inc_capitalExpenditures
# • inc_changeReceivables
# • inc_cashFlowsOtherOperating
# • inc_exchangeRateChanges
# • inc_cashAndCashEquivalentsChanges
# • inc_changeInWorkingCapital
# • inc_stockBasedCompensation
# • inc_otherNonCashItems
# • inc_freeCashFlow
# • bal_filing_date
# • bal_currency_symbol
# • bal_researchDevelopment
# • bal_effectOfAccountingCharges
# • bal_incomeBeforeTax
# • bal_minorityInterest
# • bal_netIncome
# • bal_sellingGeneralAdministrative
# • bal_sellingAndMarketingExpenses
# • bal_grossProfit
# • bal_reconciledDepreciation
# • bal_ebit
# • bal_ebitda
# • bal_depreciationAndAmortization
# • bal_nonOperatingIncomeNetOther
# • bal_operatingIncome
# • bal_otherOperatingExpenses
# • bal_interestExpense
# • bal_taxProvision
# • bal_interestIncome
# • bal_netInterestIncome
# • bal_extraordinaryItems
# • bal_nonRecurring
# • bal_otherItems
# • bal_incomeTaxExpense
# • bal_totalRevenue
# • bal_totalOperatingExpenses
# • bal_costOfRevenue
# • bal_totalOtherIncomeExpenseNet
# • bal_discontinuedOperations
# • bal_netIncomeFromContinuingOps
# • bal_netIncomeApplicableToCommonShares
# • bal_preferredStockAndOtherAdjustments
# • bal_totalAssets
# • bal_intangibleAssets
# • bal_earningAssets
# • bal_otherCurrentAssets
# • bal_totalLiab
# • bal_totalStockholderEquity
# • bal_deferredLongTermLiab
# • bal_otherCurrentLiab
# • bal_commonStock
# • bal_capitalStock
# • bal_retainedEarnings
# • bal_otherLiab
# • bal_goodWill
# • bal_otherAssets
# • bal_cash
# • bal_cashAndEquivalents
# • bal_totalCurrentLiabilities
# • bal_currentDeferredRevenue
# • bal_netDebt
# • bal_shortTermDebt
# • bal_shortLongTermDebt
# • bal_shortLongTermDebtTotal
# • bal_otherStockholderEquity
# • bal_propertyPlantEquipment
# • bal_totalCurrentAssets
# • bal_longTermInvestments
# • bal_netTangibleAssets
# • bal_shortTermInvestments
# • bal_netReceivables
# • bal_longTermDebt
# • bal_inventory
# • bal_accountsPayable
# • bal_totalPermanentEquity
# • bal_noncontrollingInterestInConsolidatedEntity
# • bal_temporaryEquityRedeemableNoncontrollingInterests
# • bal_accumulatedOtherComprehensiveIncome
# • bal_additionalPaidInCapital
# • bal_commonStockTotalEquity
# • bal_preferredStockTotalEquity
# • bal_retainedEarningsTotalEquity
# • bal_treasuryStock
# • bal_accumulatedAmortization
# • bal_nonCurrrentAssetsOther
# • bal_deferredLongTermAssetCharges
# • bal_nonCurrentAssetsTotal
# • bal_capitalLeaseObligations
# • bal_longTermDebtTotal
# • bal_nonCurrentLiabilitiesOther
# • bal_nonCurrentLiabilitiesTotal
# • bal_negativeGoodwill
# • bal_warrants
# • bal_preferredStockRedeemable
# • bal_capitalSurpluse
# • bal_liabilitiesAndStockholdersEquity
# • bal_cashAndShortTermInvestments
# • bal_propertyPlantAndEquipmentGross
# • bal_propertyPlantAndEquipmentNet
# • bal_accumulatedDepreciation
# • bal_netWorkingCapital
# • bal_netInvestedCapital
# • bal_commonStockSharesOutstanding
# • bal_investments
# • bal_changeToLiabilities
# • bal_totalCashflowsFromInvestingActivities
# • bal_netBorrowings
# • bal_totalCashFromFinancingActivities
# • bal_changeToOperatingActivities
# • bal_changeInCash
# • bal_beginPeriodCashFlow
# • bal_endPeriodCashFlow
# • bal_totalCashFromOperatingActivities
# • bal_issuanceOfCapitalStock
# • bal_depreciation
# • bal_otherCashflowsFromInvestingActivities
# • bal_dividendsPaid
# • bal_changeToInventory
# • bal_changeToAccountReceivables
# • bal_salePurchaseOfStock
# • bal_otherCashflowsFromFinancingActivities
# • bal_changeToNetincome
# • bal_capitalExpenditures
# • bal_changeReceivables
# • bal_cashFlowsOtherOperating
# • bal_exchangeRateChanges
# • bal_cashAndCashEquivalentsChanges
# • bal_changeInWorkingCapital
# • bal_stockBasedCompensation
# • bal_otherNonCashItems
# • bal_freeCashFlow
# • cf_filing_date
# • cf_currency_symbol
# • cf_researchDevelopment
# • cf_effectOfAccountingCharges
# • cf_incomeBeforeTax
# • cf_minorityInterest
# • cf_netIncome
# • cf_sellingGeneralAdministrative
# • cf_sellingAndMarketingExpenses
# • cf_grossProfit
# • cf_reconciledDepreciation
# • cf_ebit
# • cf_ebitda
# • cf_depreciationAndAmortization
# • cf_nonOperatingIncomeNetOther
# • cf_operatingIncome
# • cf_otherOperatingExpenses
# • cf_interestExpense
# • cf_taxProvision
# • cf_interestIncome
# • cf_netInterestIncome
# • cf_extraordinaryItems
# • cf_nonRecurring
# • cf_otherItems
# • cf_incomeTaxExpense
# • cf_totalRevenue
# • cf_totalOperatingExpenses
# • cf_costOfRevenue
# • cf_totalOtherIncomeExpenseNet
# • cf_discontinuedOperations
# • cf_netIncomeFromContinuingOps
# • cf_netIncomeApplicableToCommonShares
# • cf_preferredStockAndOtherAdjustments
# • cf_totalAssets
# • cf_intangibleAssets
# • cf_earningAssets
# • cf_otherCurrentAssets
# • cf_totalLiab
# • cf_totalStockholderEquity
# • cf_deferredLongTermLiab
# • cf_otherCurrentLiab
# • cf_commonStock
# • cf_capitalStock
# • cf_retainedEarnings
# • cf_otherLiab
# • cf_goodWill
# • cf_otherAssets
# • cf_cash
# • cf_cashAndEquivalents
# • cf_totalCurrentLiabilities
# • cf_currentDeferredRevenue
# • cf_netDebt
# • cf_shortTermDebt
# • cf_shortLongTermDebt
# • cf_shortLongTermDebtTotal
# • cf_otherStockholderEquity
# • cf_propertyPlantEquipment
# • cf_totalCurrentAssets
# • cf_longTermInvestments
# • cf_netTangibleAssets
# • cf_shortTermInvestments
# • cf_netReceivables
# • cf_longTermDebt
# • cf_inventory
# • cf_accountsPayable
# • cf_totalPermanentEquity
# • cf_noncontrollingInterestInConsolidatedEntity
# • cf_temporaryEquityRedeemableNoncontrollingInterests
# • cf_accumulatedOtherComprehensiveIncome
# • cf_additionalPaidInCapital
# • cf_commonStockTotalEquity
# • cf_preferredStockTotalEquity
# • cf_retainedEarningsTotalEquity
# • cf_treasuryStock
# • cf_accumulatedAmortization
# • cf_nonCurrrentAssetsOther
# • cf_deferredLongTermAssetCharges
# • cf_nonCurrentAssetsTotal
# • cf_capitalLeaseObligations
# • cf_longTermDebtTotal
# • cf_nonCurrentLiabilitiesOther
# • cf_nonCurrentLiabilitiesTotal
# • cf_negativeGoodwill
# • cf_warrants
# • cf_preferredStockRedeemable
# • cf_capitalSurpluse
# • cf_liabilitiesAndStockholdersEquity
# • cf_cashAndShortTermInvestments
# • cf_propertyPlantAndEquipmentGross
# • cf_propertyPlantAndEquipmentNet
# • cf_accumulatedDepreciation
# • cf_netWorkingCapital
# • cf_netInvestedCapital
# • cf_commonStockSharesOutstanding
# • cf_investments
# • cf_changeToLiabilities
# • cf_totalCashflowsFromInvestingActivities
# • cf_netBorrowings
# • cf_totalCashFromFinancingActivities
# • cf_changeToOperatingActivities
# • cf_changeInCash
# • cf_beginPeriodCashFlow
# • cf_endPeriodCashFlow
# • cf_totalCashFromOperatingActivities
# • cf_issuanceOfCapitalStock
# • cf_depreciation
# • cf_otherCashflowsFromInvestingActivities
# • cf_dividendsPaid
# • cf_changeToInventory
# • cf_changeToAccountReceivables
# • cf_salePurchaseOfStock
# • cf_otherCashflowsFromFinancingActivities
# • cf_changeToNetincome
# • cf_capitalExpenditures
# • cf_changeReceivables
# • cf_cashFlowsOtherOperating
# • cf_exchangeRateChanges
# • cf_cashAndCashEquivalentsChanges
# • cf_changeInWorkingCapital
# • cf_stockBasedCompensation
# • cf_otherNonCashItems
# • cf_freeCashFlow
# • ticker
# • sector
# • industry
# • return_1m
# • return_3m
# • return_6m
# • return_1y
# • target_1m_5
# • target_3m_10
# • target_3m_15
# • target_6m_20
# • target_6m_25
# • target_1y_30
# • target_3m_10_and_6m_20
# • target_3m_15_and_6m_25
# • rsi_4
# • rsi_7
# • rsi_14
# • rsi_28
# • rsi_weekly_7
# • price_rel_sma50d
# • price_rel_sma100d
# • price_rel_sma200d
# • price_rel_sma26w
# • price_rel_sma52w
# • price_rel_sma156w
# • price_rel_sma260w
# • returns_1w
# • returns_1m
# • macd
# • macd_signal
# • volume_sma_20d
# • volume_rel_20d
# • volume_week
# • volume_sma_12w
# • volume_rel_12w

# %%
df[df['ticker'] == 'A'].isna().sum()
# Out:
# ticker           0
# date             0
# pe_ttm           0
# pe_rel_index     0
# rsi_14          14
# macd             0
# macd_signal      0
# returns_1w       5
# returns_1m      21
# bb_upper        19
# bb_lower        19
# dtype: int64
